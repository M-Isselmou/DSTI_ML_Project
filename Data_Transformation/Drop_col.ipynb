# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


cyberdata=pd.read_csv("cybersecurity_attacks.csv")
cyberdata_drop=cyberdata
cyberdata_drop.head()
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ... Action Taken  \
# ...

# %% [markdown]
# ### We select the cols that we want to delet

# %%
drop_cols = cyberdata_drop[["Malware Indicators", "Alerts/Warnings", "Firewall Logs", "IDS/IPS Alerts","Timestamp","Source Port",	"Destination Port",
                            "Payload Data","User Information"]]
drop_cols
# Out:
#       Malware Indicators  Alerts/Warnings Firewall Logs IDS/IPS Alerts  \
# 0           IoC Detected              NaN      Log Data            NaN
# 1           IoC Detected              NaN      Log Data            NaN
# 2           IoC Detected  Alert Triggered      Log Data     Alert Data
# 3                    NaN  Alert Triggered           NaN     Alert Data
# 4                    NaN  Alert Triggered           NaN     Alert Data
# ...                  ...              ...           ...            ...
# 39995       IoC Detected              NaN      Log Data     Alert Data
# 39996       IoC Detected              NaN      Log Data            NaN
# 39997       IoC Detected              NaN      Log Data     Alert Data
# 39998       IoC Detected  Alert Triggered      Log Data            NaN
# 39999                NaN  Alert Triggered      Log Data     Alert Data
#
#                  Timestamp  Source Port  Destination Port  \
# ...

# %%
cyberdata_drop = cyberdata_drop.drop(columns=drop_cols)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cyberdata_drop = cyberdata_drop.drop(columns=drop_cols)
#       2 cyberdata_drop.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
cyberdata_drop.head()
# Out:
#   Source IP Address Destination IP Address Protocol  Packet Length  \
# 0     103.216.15.12           84.9.164.252     ICMP            503
# 1    78.199.217.198         66.191.137.154     ICMP           1174
# 2      63.79.210.48          198.219.82.17      UDP            306
# 3     163.42.196.10        101.228.192.255      UDP            385
# 4     71.166.185.76        189.243.174.238      TCP           1462
#
#   Packet Type Traffic Type  Anomaly Scores Attack Type Attack Signature  \
# 0        Data         HTTP           28.67     Malware  Known Pattern B
# 1        Data         HTTP           51.50     Malware  Known Pattern A
# 2     Control         HTTP           87.42        DDoS  Known Pattern B
# 3        Data         HTTP           15.79     Malware  Known Pattern B
# 4        Data          DNS            0.52        DDoS  Known Pattern B
#
#   Action Taken Severity Level  \
# 0       Logged            Low
# 1      Blocked            Low
# 2      Ignored            Low
# ...

# %%
csv_file_path = "cyberdata_drop.csv"
cyberdata_drop.to_csv(csv_file_path, index=False)

# %%
csv_file_path
# Out:
# 'cyberdata_drop.csv'
